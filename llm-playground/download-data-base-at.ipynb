# %% [markdown]
# # Downloading the at database

# %%
from decouple import Config, RepositoryEnv
import requests
import pandas as pd
import numpy as np

# %%
# Creation d'une classe pour dialoguer plus simplement avec l'API de AT
class APIClient:
    def __init__(self,x_auth_token):
        self.x_auth_token = x_auth_token
        self.base_uri = self.get_api_base_url()
        self.bearer_token = self.get_bearer_token()
        self.session = self.create_session() 

    def get_api_base_url(self):
        return 'https://aides-territoires.beta.gouv.fr/api/'

    def get_bearer_token(self):
        url = 'https://aides-territoires.beta.gouv.fr/api/connexion/'
        headers = {
            'accept': 'application/json',
            'Content-Type': 'application/json',
            'X-AUTH-TOKEN': self.x_auth_token
        }
        response = requests.post(url, headers=headers)
        response.raise_for_status()
        return response.json()['token']

    def create_session(self):
        session = requests.Session()
        session.headers.update({
            'Authorization': f'Bearer {self.bearer_token}',
            'Accept': 'application/json'
        })
        return session

    def simple_request_endpoint(self, endpoint, method='GET'):
        url = f'{self.base_uri}{endpoint}'
        response = self.session.request(method, url)
        response.raise_for_status()
        return response

    def simple_request_url(self, url, method='GET'):
        response = self.session.request(method, url)
        response.raise_for_status()
        return response

# %% [markdown]
# ### Collect perimeters data

# %%
config = Config(RepositoryEnv('.env'))
at_x_auth_token = config('X_AUTH_TOKEN')
    
# Utilisation vous avez besoin d'un x_auth_token fournit par aide territoires
client = APIClient(at_x_auth_token)

# %%
response = client.simple_request_endpoint('perimeters/?page=1&itemsPerPage=100')
data = response.json()
data_collect = data['results']
error_counter = 0
while data['next'] or error_counter >10:
    try:
        url = data['next']
        print(url)
        response = client.simple_request_url(url)
        data = response.json()
        data_collect = data_collect + data['results']
        error_counter = 0
    except Exception as error:
        print(error)
        error_counter += 1
# Out:
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=2&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=3&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=4&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=5&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=6&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=7&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=8&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=9&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=10&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=11&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=12&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=13&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=14&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=15&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=16&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=17&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=18&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=19&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=20&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=21&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=22&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=23&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=24&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=25&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=26&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=27&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=28&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=29&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=30&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=31&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=32&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=33&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=34&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=35&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=36&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=37&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=38&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=39&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=40&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=41&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=42&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=43&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=44&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=45&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=46&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=47&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=48&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=49&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=50&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=51&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=52&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=53&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=54&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=55&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=56&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=57&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=58&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=59&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=60&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=61&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=62&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=63&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=64&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=65&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=66&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=67&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=68&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=69&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=70&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=71&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=72&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=73&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=74&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=75&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=76&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=77&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=78&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=79&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=80&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=81&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=82&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=83&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=84&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=85&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=86&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=87&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=88&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=89&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=90&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=91&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=92&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=93&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=94&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=95&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=96&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=97&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=98&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=99&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=100&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=101&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=102&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=103&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=104&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=105&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=106&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=107&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=108&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=109&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=110&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=111&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=112&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=113&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=114&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=115&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=116&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=117&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=118&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=119&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=120&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=121&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=122&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=123&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=124&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=125&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=126&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=127&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=128&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=129&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=130&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=131&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=132&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page=133&itemsPerPage=100
# https://aides-territoires.beta.gouv.fr/api/perimeters/?page
itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=15&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=16&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=17&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=18&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=19&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=20&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=21&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=22&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=23&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=24&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=25&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=26&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=27&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=28&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=29&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=30&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=31&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=32&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=33&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=34&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=35&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=36&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=37&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=38&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=39&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=40&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=41&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=42&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=43&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=44&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=45&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=46&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=47&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=48&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=49&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=50&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=51&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=52&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=53&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=54&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=55&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=56&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=57&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=58&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=59&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=60&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=61&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=62&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=63&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=64&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=65&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=66&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=67&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=68&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=69&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=70&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=71&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=72&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=73&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=74&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=75&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=76&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=77&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=78&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=79&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=80&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=81&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=82&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=83&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=84&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=85&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=86&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=87&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=88&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=89&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=90&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=91&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=92&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=93&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=94&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=95&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=96&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=97&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=98&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=99&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=100&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=101&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=102&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=103&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=104&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=105&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=106&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=107&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=108&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=109&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=110&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=111&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=112&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=113&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=114&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=115&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=116&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=117&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=118&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=119&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=120&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=121&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=122&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=123&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=124&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=125&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=126&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=127&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=128&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=129&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=130&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=131&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=132&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=133&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=134&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=135&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=136&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=137&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=138&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=139&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=140&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=141&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=142&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=143&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=144&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=145&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=146&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=147&itemsPerPage=30
# https://aides-territoires.beta.gouv.fr/api/aids/?page=148&itemsPerPage=30

# %%
data_at = pd.DataFrame(data_collect).set_index("id")

data_at_select_full = data_at.dropna(subset='description')

data_at_select = data_at_select_full.copy()

sub_min_description = 2000

data_at_select = data_at_select[data_at_select['description'].apply(len)>sub_min_description].reset_index(drop=True)


data_at_select_full.to_csv('hard-database/data_at_select_full.csv')
data_at_select.to_csv('hard-database/data_at_select.csv')

# %% [markdown]
# # Adding detail with AI

# %%
from decouple import Config, RepositoryEnv
from markdownify import markdownify as md
import json

from ollama_interaction import generate_ollama_request,generate_ollama_embeddings

# %%
config = Config(RepositoryEnv('.env'))

ollama_api_url = config('OLLAMA_API_URL')
ollama_bearer_token = config('OLLAMA_BEARER_TOKEN')

# %%
def converte_to_md(html_text):
    if html_text:
        return md(html_text)
    else:
        return None

# %%
data_at['description_md'] = data_at['description'].apply(converte_to_md)
data_at['eligibility_md'] = data_at['eligibility'].apply(converte_to_md)
# Out:
# c:\Users\Ian METELSKI\Desktop\code\main\vapp\decision-ia\llm-playground\.conda\Lib\site-packages\markdownify\__init__.py:104: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html, 'html.parser')

# %%
def check_text_viability(text:str,min_char:int=5)->bool:
    try:
        if text:
            if len(text)>min_char:
                return True
            else:
                return False
        else:
            return False
    except:
        return False

# %%
def gen_context_len(text:str,prompt_system:str,ollama_api_url:str,ollama_bearer_token:str,model_options:dict,delta_token:int=0,request_options:dict={})->int:
    request_options["num_ctx"] = request_options.get("num_ctx", 16384)
    request_options["num_predict"] = request_options.get("num_predict",1)


    prompt_user = f"{text}"
    try :
        if check_text_viability(text):
            response = generate_ollama_request(
                prompt_system=prompt_system,
                response_format=None,
                prompt_user=prompt_user,
                ollama_api_url=ollama_api_url,
                bearer_token=ollama_bearer_token,
                model_options = model_options,  # Default to None
                request_options= request_options,  # Default to None
                seed=0,
                )
            token_numb = len(response['context']) - delta_token
            return token_numb
        else:
            token_numb = 0
            return 0
    except:
        return None

# %% [markdown]
# It's a little bit dumb to make a generation request but right now ollama dosn't have a tokenize endpoint so we do a dumy generation of 1 token to get the context len.

# %%
model_options = {
    "best_context":64000,
    "max_context":128000,
    "top_k": 20,
    "top_p": 0.9,
    "temperature": 0.8,
    "repeat_penalty": 1.2,
    "presence_penalty": 1.5,
    "frequency_penalty": 1.0,
}
model = "llama3.2:1b"

prompt_system = f""
prompt_user = ""

token_numb_description_md_list = []
token_numb_description_list  = []

token_numb_eligibility_md_list  = []
token_numb_eligibility_list = []

for i, row in data_at.iterrows():
    # print('------')
    row_description_md = row['description_md']
    row_description = row['description']

    row_eligibility_md = row['eligibility_md']
    row_eligibility = row['eligibility']

    token_numb_description_md = gen_context_len(row_description_md,prompt_system,ollama_api_url,ollama_bearer_token,model_options)
    token_numb_description_md_list.append(token_numb_description_md)
    # print(token_numb_description_md)

    token_numb_description = gen_context_len(row_description,prompt_system,ollama_api_url,ollama_bearer_token,model_options)
    token_numb_description_list.append(token_numb_description)
    # print(token_numb_description)

    token_numb_eligibility_md = gen_context_len(row_eligibility_md,prompt_system,ollama_api_url,ollama_bearer_token,model_options)
    token_numb_eligibility_md_list.append(token_numb_eligibility_md)
    # print(token_numb_eligibility_md)

    token_numb_eligibility = gen_context_len(row_eligibility,prompt_system,ollama_api_url,ollama_bearer_token,model_options)
    token_numb_eligibility_list.append(token_numb_eligibility)
    # print(token_numb_eligibility)

# %%
data_at['token_numb_description_md'] = token_numb_description_md_list
data_at['token_numb_description'] = token_numb_description_list

data_at['token_numb_eligibility_md'] = token_numb_eligibility_md_list
data_at['token_numb_eligibility'] = token_numb_eligibility_list

# %%
data_at.to_csv('hard-database/data_at_select_ai.csv')

# %% [markdown]
# # Embedding generation

# %%
embedding_list = []
for description in data_at['description_md']:
    response = generate_ollama_embeddings(prompt=description,ollama_api_url=ollama_api_url)
    emb = response['embedding']
    embedding_list.append(emb)
    # print('ok')
data_at['embedding_md'] = embedding_list

# %%
data_at.to_csv('hard-database/data_at_select_ai_emb.csv')

# %% [markdown]
# # Graph extraction

# %%
import plotly.express as px

px.scatter(
    data_at,
    x='token_numb_eligibility_md',
    y='token_numb_eligibility',
    title='Number of token for sub eligibility with markdown conversion vs html original'
    ).write_html('graph/token_count_eligibility.html')

px.scatter(
    data_at,
    x='token_numb_description_md',
    y='token_numb_description',
    title='Number of token for sub description with markdown conversion vs html original'
    ).write_html('graph/token_count_description.html')
